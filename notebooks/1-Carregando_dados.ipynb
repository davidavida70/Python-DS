# %%
#manipulação de dados
import pandas as pd

# %%
# carregando dados de diferentes tipos de arquivos

df = pd.read_csv('../data-scripts/1/base_vendas.csv')
df.head()
# Out:
#    matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 3              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 4              123456111       José Maria  Vendedor       CL001  Loja Matriz
#
#    codigo_produto    descricao_produto         Categoria preco_custo  \
# 0           10013                Fogão  Eletrodomésticos       210,9
# 1           10018              Colchão              Casa       109,9
# 2           10014            Geladeira  Eletrodomésticos       699,9
# 3           10001           Smartphone       Eletrônicos       899,9
# 4           10004  Máquina Lavar Roupa  Eletrodomésticos        1099
#
#   valor_unitario  quantidade comissao          dt_venda        dt_entrega
# ...

# %%
# read_csv por padrão usa ',' como separador
# outros separadores ';' - '\t'

df = pd.read_csv('../data-scripts/1/base_vendas_ponto_virgula.csv', sep=';')
df.head()
# Out:
#    matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 3              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 4              123456111       José Maria  Vendedor       CL001  Loja Matriz
#
#    codigo_produto    descricao_produto         Categoria preco_custo  \
# 0           10013                Fogão  Eletrodomésticos       210,9
# 1           10018              Colchão              Casa       109,9
# 2           10014            Geladeira  Eletrodomésticos       699,9
# 3           10001           Smartphone       Eletrônicos       899,9
# 4           10004  Máquina Lavar Roupa  Eletrodomésticos        1099
#
#   valor_unitario  quantidade comissao          dt_venda        dt_entrega
# ...

# %%
df = pd.read_csv('../data-scripts/1/base_vendas_tab.tsv', sep='\t')
df.head()
# Out:
#    matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 3              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 4              123456111       José Maria  Vendedor       CL001  Loja Matriz
#
#    codigo_produto    descricao_produto         Categoria preco_custo  \
# 0           10013                Fogão  Eletrodomésticos       210,9
# 1           10018              Colchão              Casa       109,9
# 2           10014            Geladeira  Eletrodomésticos       699,9
# 3           10001           Smartphone       Eletrônicos       899,9
# 4           10004  Máquina Lavar Roupa  Eletrodomésticos        1099
#
#   valor_unitario  quantidade comissao          dt_venda        dt_entrega
# ...

# %%
df = pd.read_hdf('../data-scripts/1/base_vendas.h5')
df.head()
# Out:
#    matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 3              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 4              123456111       José Maria  Vendedor       CL001  Loja Matriz
#
#    codigo_produto    descricao_produto         Categoria preco_custo  \
# 0           10013                Fogão  Eletrodomésticos       210,9
# 1           10018              Colchão              Casa       109,9
# 2           10014            Geladeira  Eletrodomésticos       699,9
# 3           10001           Smartphone       Eletrônicos       899,9
# 4           10004  Máquina Lavar Roupa  Eletrodomésticos        1099
#
#   valor_unitario  quantidade comissao          dt_venda        dt_entrega
# ...

# %%
df = pd.read_json('../data-scripts/1/base_vendas.json')
df.head()
# Out:
#    matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 3              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 4              123456111       José Maria  Vendedor       CL001  Loja Matriz
#
#    codigo_produto    descricao_produto         Categoria preco_custo  \
# 0           10013                Fogão  Eletrodomésticos       210,9
# 1           10018              Colchão              Casa       109,9
# 2           10014            Geladeira  Eletrodomésticos       699,9
# 3           10001           Smartphone       Eletrônicos       899,9
# 4           10004  Máquina Lavar Roupa  Eletrodomésticos        1099
#
#   valor_unitario  quantidade comissao          dt_venda        dt_entrega
# ...

# %%
df = pd.read_xml('../data-scripts/1/base_vendas.xml')
df.head()
# Out:
#    index  matricula_funcionario nome_funcionario     cargo codigo_loja  \
# 0      0              123456111       José Maria  Vendedor       CL001
# 1      1              123456111       José Maria  Vendedor       CL001
# 2      2              123456111       José Maria  Vendedor       CL001
# 3      3              123456111       José Maria  Vendedor       CL001
# 4      4              123456111       José Maria  Vendedor       CL001
#
#      nome_loja  codigo_produto    descricao_produto         categoria  \
# 0  Loja Matriz           10013                Fogão  Eletrodomésticos
# 1  Loja Matriz           10018              Colchão              Casa
# 2  Loja Matriz           10014            Geladeira  Eletrodomésticos
# 3  Loja Matriz           10001           Smartphone       Eletrônicos
# 4  Loja Matriz           10004  Máquina Lavar Roupa  Eletrodomésticos
#
#   preco_custo valor_unitario  quantidade comissao          dt_venda  \
# ...

# %%
# manipulação de dados no excel

df = pd.read_excel('../data-scripts/1/Vendas.xlsx', sheet_name='base_vendas')
df.head()
# Out:
#    matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 3              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 4              123456111       José Maria  Vendedor       CL001  Loja Matriz
#
#    codigo_produto    descricao_produto         Categoria  preco_custo  \
# 0           10013                Fogão  Eletrodomésticos        210.9
# 1           10018              Colchão              Casa        109.9
# 2           10014            Geladeira  Eletrodomésticos        699.9
# 3           10001           Smartphone       Eletrônicos        899.9
# 4           10004  Máquina Lavar Roupa  Eletrodomésticos       1099.0
#
#    valor_unitario  quantidade  comissao            dt_venda  \
# ...

# %%
listas = pd.read_html('../data-scripts/1/base_vendas.html')
df = listas[0]
df.head()
# Out:
#    matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 3              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 4              123456111       José Maria  Vendedor       CL001  Loja Matriz
#
#    codigo_produto    descricao_produto         Categoria  preco_custo  \
# 0           10013                Fogão  Eletrodomésticos         2109
# 1           10018              Colchão              Casa         1099
# 2           10014            Geladeira  Eletrodomésticos         6999
# 3           10001           Smartphone       Eletrônicos         8999
# 4           10004  Máquina Lavar Roupa  Eletrodomésticos         1099
#
#    valor_unitario  quantidade  comissao          dt_venda        dt_entrega
# ...

# %%
# importando tabela de site (Wikipedia)

lista = pd.read_html('../data-scripts/1/Predefinição_Lista de PSP Models – Wikipédia, a enciclopédia livre.html')
df = lista[0]
df.head()
# Out:
#       Séries  Imagem                                           Conexões  \
# 0   PSP-1000     NaN  USB 2.0, UMD, Serial Port, Headphone Jack, Mem...
# 1   PSP-2000     NaN  USB 2.0, UMD, Video Out and Mic Port, Headphon...
# 2   PSP-3000     NaN  USB 2.0, UMD, Video Out, Microphone, Headphone...
# 3     PSP Go     NaN  All in One Port, Headphone Jack, Mic, Memory S...
# 4  PSP-E1000     NaN  USB 2.0, UMD, Headphone Jack, Memory Stick PRO...
#
#              Conectividade Wireless  \
# 0               802.11b Wi-Fi, IRDA
# 1                     802.11b Wi-Fi
# 2                     802.11b Wi-Fi
# 3  802.11b Wi-Fi, Bluetooth 2.1 EDR
# 4                               Não
#
#                   RAM e Armazenamento Interno                     CPU  \
# 0                  32MB, 32MB System Software  MIPS R4000 at 1~333Mhz
# 1                  64MB, 64MB System Software  MIPS R4000 at 1~333Mhz
# 2                  64MB, 64MB System Software  MIPS R4000 at 1~333Mhz
# ...

# %%
# importando banco de dados

import sqlite3

# %%
conn = sqlite3.connect('../data-scripts/1/vendas.db')

# %%
df = pd.read_sql_query('select * from pedidos', conn)
df.head()
# Out:
#   matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0             123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1             123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2             123456111       José Maria  Vendedor       CL001  Loja Matriz
# 3             123456111       José Maria  Vendedor       CL001  Loja Matriz
# 4             123456111       José Maria  Vendedor       CL001  Loja Matriz
#
#   codigo_produto    descricao_produto         Categoria preco_custo  \
# 0          10013                Fogão  Eletrodomésticos       210,9
# 1          10018              Colchão              Casa       109,9
# 2          10014            Geladeira  Eletrodomésticos       699,9
# 3          10001           Smartphone       Eletrônicos       899,9
# 4          10004  Máquina Lavar Roupa  Eletrodomésticos        1099
#
#   valor_unitario quantidade comissao          dt_venda        dt_entrega
# ...

# %%
# exportando para arquivo excel

df.to_excel('../data-scripts/1/base_vendas.xlsx')
