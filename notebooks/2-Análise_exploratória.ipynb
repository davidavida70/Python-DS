# %% [markdown]
# #CRISP-DM
#
# 1. Compreensão do Negócio: Definir os objetivos do projeto e os requisitos do
# ponto de vista do negócio.
#
# 2. Compreensão dos Dados: Coletar e explorar os dados para entender sua estrutura e qualidade, identificando quais variáveis são relevantes.
#
# 3. Preparação dos Dados: Selecionar, limpar e transformar os dados brutos em um formato adequado para a modelagem. Esta fase pode consumir até 60% do tempo do projeto.
#
# 4. Modelagem: Selecionar e aplicar as técnicas de modelagem apropriadas para analisar os dados e encontrar padrões.
#
# 5. Avaliação: Avaliar os modelos construídos para verificar se eles atendem aos objetivos definidos na fase de compreensão do negócio e se são eficazes.
#
# 6. Implementação: Implantar o modelo final em produção, seja através de relatórios, dashboards ou outras aplicações, para que ele possa gerar valor de forma contínua.

# %%
import pandas as pd

# %%
df_vendas = pd.read_csv('../data-scripts/2/base_vendas.csv')

# %%
# .head(x) - padrão mostra as primeiras x linhas
df_vendas.head(3)
# Out:
#    matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2              123456111       José Maria  Vendedor       CL001  Loja Matriz
#
#    codigo_produto descricao_produto         Categoria preco_custo  \
# 0           10013             Fogão  Eletrodomésticos       210,9
# 1           10018           Colchão              Casa       109,9
# 2           10014         Geladeira  Eletrodomésticos       699,9
#
#   valor_unitario  quantidade comissao          dt_venda        dt_entrega
# 0          404,1           1      NaN  28/09/2020 16:19  05/10/2020 16:31
# 1          249,9           1      NaN  07/03/2020 12:47  08/03/2020 12:47
# 2         1346,9           1      NaN  21/04/2019 10:48  23/04/2019 15:55

# %%
# .tail(x) - padrão mostra as últimas x linhas
df_vendas.tail(3)
# Out:
#       matricula_funcionario Nome Funcionario     Cargo codigo_loja  nome_loja  \
# 2997              123457113      Victor Hugo  Vendedor       CL004  Filial ES
# 2998              123457113      Victor Hugo  Vendedor       CL004  Filial ES
# 2999              123457113      Victor Hugo  Vendedor       CL004  Filial ES
#
#       codigo_produto    descricao_produto         Categoria preco_custo  \
# 2997           10007            Batedeira           Cozinha        49,9
# 2998           10010  Fritadeira elétrica           Cozinha       187,9
# 2999           10004  Máquina Lavar Roupa  Eletrodomésticos        1099
#
#      valor_unitario  quantidade comissao          dt_venda        dt_entrega
# 2997           95,9           3      NaN  08/08/2020 14:46  09/08/2020 14:07
# 2998            340           3      NaN  19/12/2019 09:21  19/12/2019 10:51
# 2999         1709,1           3     0,09  18/03/2019 15:40  23/03/2019 17:52

# %%
# mostra em dataFrames pequenos todas as linhas
# Dataframes grandes mostra as 5 primeiras e as 5 últimas
display(df_vendas)
# Out:
#       matricula_funcionario Nome Funcionario     Cargo codigo_loja  \
# 0                 123456111       José Maria  Vendedor       CL001
# 1                 123456111       José Maria  Vendedor       CL001
# 2                 123456111       José Maria  Vendedor       CL001
# 3                 123456111       José Maria  Vendedor       CL001
# 4                 123456111       José Maria  Vendedor       CL001
# ...                     ...              ...       ...         ...
# 2995              123457113      Victor Hugo  Vendedor       CL004
# 2996              123457113      Victor Hugo  Vendedor       CL004
# 2997              123457113      Victor Hugo  Vendedor       CL004
# 2998              123457113      Victor Hugo  Vendedor       CL004
# 2999              123457113      Victor Hugo  Vendedor       CL004
#
#         nome_loja  codigo_produto    descricao_produto         Categoria  \
# 0     Loja Matriz           10013                Fogão  Eletrodomésticos
# ...

# %%
# visão geral da base de dados (é possível observar que algumas colunas estão com o tipo incorreto e existem linhas nulas na comissão)
df_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   matricula_funcionario  3000 non-null   int64
#  1   Nome Funcionario       3000 non-null   object
#  2   Cargo                  3000 non-null   object
#  3   codigo_loja            3000 non-null   object
#  4   nome_loja              3000 non-null   object
#  5   codigo_produto         3000 non-null   int64
#  6   descricao_produto      3000 non-null   object
#  7   Categoria              3000 non-null   object
#  8   preco_custo            3000 non-null   object
#  9   valor_unitario         3000 non-null   object
#  10  quantidade             3000 non-null   int64
#  11  comissao               159 non-null    object
#  12  dt_venda               3000 non-null   object
#  13  dt_entrega             3000 non-null   object
# dtypes: int64(3), object(11)
# ...

# %%
# (linhas, colunas)
df_vendas.shape
# Out:
# (3000, 14)

# %%
# utilidades para dados numéricos, nem sempre tudo pode ser aproveitado
df_vendas.describe().round(2)
# Out:
#        matricula_funcionario  codigo_produto  quantidade
# count           3.000000e+03         3000.00     3000.00
# mean            1.234567e+08        10010.47        2.45
# std             3.490000e+02            5.77        1.11
# min             1.234561e+08        10001.00        1.00
# 25%             1.234563e+08        10006.00        1.00
# 50%             1.234567e+08        10011.00        2.00
# 75%             1.234570e+08        10015.00        3.00
# max             1.234571e+08        10020.00        4.00

# %%
# incluindo dados não numéricos (strings, datetime)
df_vendas.describe(include='object')
# Out:
#        Nome Funcionario     Cargo codigo_loja    nome_loja descricao_produto  \
# count              3000      3000        3000         3000              3000
# unique               12         1           4            4                20
# top          José Maria  Vendedor       CL001  Loja Matriz   Aspirador de pó
# freq                280      3000         793          793               173
#
#        Categoria preco_custo valor_unitario comissao          dt_venda  \
# count       3000        3000           3000      159              3000
# unique         4          20             19        4              2994
# top         Casa        88,9          189,9     0,05  09/07/2019 16:05
# freq         907         173            316       49                 2
#
#               dt_entrega
# count               3000
# unique              2989
# top     09/12/2019 10:12
# freq                   2

# %%
# quantidade de linhas duplicadas
df_vendas.duplicated().sum()
# Out:
# np.int64(0)

# %%
# quantidade de linhas com informações nulas de cada coluna
# df_vendas.isnull().sum() mesma coisa
df_vendas.isna().sum()
# Out:
# matricula_funcionario       0
# Nome Funcionario            0
# Cargo                       0
# codigo_loja                 0
# nome_loja                   0
# codigo_produto              0
# descricao_produto           0
# Categoria                   0
# preco_custo                 0
# valor_unitario              0
# quantidade                  0
# comissao                 2841
# dt_venda                    0
# dt_entrega                  0
# dtype: int64

# %%
# instâncias distintas das colunas
df_vendas.nunique()
# Out:
# matricula_funcionario      12
# Nome Funcionario           12
# Cargo                       1
# codigo_loja                 4
# nome_loja                   4
# codigo_produto             20
# descricao_produto          20
# Categoria                   4
# preco_custo                20
# valor_unitario             19
# quantidade                  4
# comissao                    4
# dt_venda                 2994
# dt_entrega               2989
# dtype: int64

# %%
# instâncias distintas da coluna especificada
df_vendas.nome_loja.unique()
# Out:
# array(['Loja Matriz', 'Filial MG', 'Filial SP', 'Filial ES'], dtype=object)

# %%
# outra forma
df_vendas['Nome Funcionario'].unique()
# Out:
# array(['José Maria', 'Maria das Graças', 'Jorge Mateus', 'Marta Cury',
#        'Ricardo Lemos', 'Reginaldo Sodré', 'Felipe Marinho',
#        'Marcos Coelho', 'Rita Sampaio', 'Mário Henrique', 'Pamela Lima',
#        'Victor Hugo'], dtype=object)

# %%
# nomes de todas as colunas
df_vendas.columns
# Out:
# Index(['matricula_funcionario', 'Nome Funcionario', 'Cargo', 'codigo_loja',
#        'nome_loja', 'codigo_produto', 'descricao_produto', 'Categoria',
#        'preco_custo', 'valor_unitario', 'quantidade', 'comissao', 'dt_venda',
#        'dt_entrega'],
#       dtype='object')

# %% [markdown]
# ##Exercício

# %%
# base airbnb
df_bnb = pd.read_csv('../data-scripts/2/listings.csv')
display(df_bnb)
# Out:
#                         id                                               name  \
# 0                    17878  Very Nice 2Br in Copacabana w. balcony, fast WiFi
# 1                    25026    Beautiful Modern Decorated Studio in Copacabana
# 2                    35764    COPACABANA SEA BREEZE  -  RIO - 25  X Superhost
# 3                    48305           Bright 6bed Penthouse Seconds from Beach
# 4                    48901  Extra large 4BD 3BT on the AtlanticAve. Copaca...
# ...                    ...                                                ...
# 42567  1450108622211032237                                Aconchego Constante
# 42568  1450108828266063076                                       Quarto casal
# 42569  1450124185987579534                      Cama em Dorm Misto (9) com AC
# 42570  1450124362124784419                                  Quarto para casal
# 42571  1450147164497105593                                Loft mar-Recreio RJ
#
# ...

# %%
df_bnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42572 entries, 0 to 42571
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              42572 non-null  int64
#  1   name                            42572 non-null  object
#  2   host_id                         42572 non-null  int64
#  3   host_name                       41092 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   42572 non-null  object
#  6   latitude                        42572 non-null  float64
#  7   longitude                       42572 non-null  float64
#  8   room_type                       42572 non-null  object
#  9   price                           38992 non-null  float64
#  10  minimum_nights                  42572 non-null  int64
#  11  number_of_reviews               42572 non-null  int64
# ...

# %%
df_bnb.describe(include='object')
# Out:
#                              name host_name neighbourhood        room_type  \
# count                       42572     41092         42572            42572
# unique                      40290      7058           154                4
# top     Apartamento em Copacabana    Daniel    Copacabana  Entire home/apt
# freq                          174       431         13099            33990
#
#        last_review
# count        33949
# unique        1419
# top     2025-06-22
# freq          2685

# %%
df_bnb.describe().round(2)
# Out:
#                  id       host_id  neighbourhood_group  latitude  longitude  \
# count  4.257200e+04  4.257200e+04                  0.0  42572.00   42572.00
# mean   7.837189e+17  2.315791e+08                  NaN    -22.97     -43.25
# std    5.521959e+17  2.152555e+08                  NaN      0.04       0.10
# min    1.787800e+04  3.607000e+03                  NaN    -23.07     -43.72
# 25%    4.786936e+07  3.656636e+07                  NaN    -22.98     -43.30
# 50%    9.993601e+17  1.550753e+08                  NaN    -22.97     -43.19
# 75%    1.284331e+18  4.253404e+08                  NaN    -22.95     -43.18
# max    1.450245e+18  7.030729e+08                  NaN    -22.75     -43.10
#
#            price  minimum_nights  number_of_reviews  reviews_per_month  \
# count   38992.00        42572.00           42572.00           33949.00
# mean      688.01            3.64              25.12               1.20
# ...

# %%
df_bnb.isna().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                          1480
# neighbourhood_group               42572
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                              3580
# minimum_nights                        0
# number_of_reviews                     0
# last_review                        8623
# reviews_per_month                  8623
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                           42572
# dtype: int64

# %%
df_bnb.nunique()
# Out:
# id                                42572
# name                              40290
# host_id                           24935
# host_name                          7058
# neighbourhood_group                   0
# neighbourhood                       154
# latitude                          26063
# longitude                         27444
# room_type                             4
# price                              2434
# minimum_nights                       69
# number_of_reviews                   425
# last_review                        1419
# reviews_per_month                   766
# calculated_host_listings_count       66
# availability_365                    366
# number_of_reviews_ltm               113
# license                               0
# dtype: int64

# %%
df_bnb.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_bnb.host_name.unique()
# Out:
# array(['Matthias', 'Viviane', 'Patricia Miranda & Paulo', ...,
#        'Joel Messias', 'Erika Aparecida', 'Adriano Marques De Souza'],
#       dtype=object)

# %%
df_bnb['neighbourhood'].unique()
# Out:
# array(['Copacabana', 'Ipanema', 'Barra da Tijuca', 'Joá', 'Santa Teresa',
#        'Gávea', 'Leblon', 'Jacarepaguá', 'Botafogo',
#        'Recreio dos Bandeirantes', 'Itanhangá', 'Praça Seca',
#        'Laranjeiras', 'Lagoa', 'Humaitá', 'Vidigal', 'Centro',
#        'Jardim Botânico', 'Tijuca', 'Flamengo', 'São Conrado', 'Urca',
#        'Leme', 'Vila da Penha', 'Glória', 'Vargem Pequena',
#        'Alto da Boa Vista', 'Cosme Velho', 'Rocinha', 'Vargem Grande',
#        'Penha Circular', 'Estácio', 'Bangu', 'Praça da Bandeira',
#        'Taquara', 'Bonsucesso', 'Gamboa', 'Barra de Guaratiba',
#        'Rio Comprido', 'Catete', 'Maracanã', 'Engenho Novo', 'Curicica',
#        'Vila Isabel', 'Piedade', 'São Francisco Xavier', 'Cachambi',
#        'Guaratiba', 'Portuguesa', 'Cavalcanti', 'Grajaú', 'Higienópolis',
#        'Anil', 'Rocha Miranda', 'Camorim', 'Freguesia (Jacarepaguá)',
#        'São Cristóvão', 'Riachuelo', 'Todos os Santos', 'Campo Grande',
# ...

# %%
df_bnb.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
# base titanic
df_titanic = pd.read_csv('../data-scripts/2/Titanic Dataset.csv', sep=';')
display(df_titanic)
# Out:
#       Classe  Sobreviveu                                             Nome  \
# 0          1           1                    Allen, Miss. Elisabeth Walton
# 1          1           1                   Allison, Master. Hudson Trevor
# 2          1           0                     Allison, Miss. Helen Loraine
# 3          1           0             Allison, Mr. Hudson Joshua Creighton
# 4          1           0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...         ...                                              ...
# 1304       3           0                             Zabour, Miss. Hileni
# 1305       3           0                            Zabour, Miss. Thamine
# 1306       3           0                        Zakarian, Mr. Mapriededer
# 1307       3           0                              Zakarian, Mr. Ortin
# 1308       3           0                               Zimmerman, Mr. Leo
#
#         Sexo  Idade  Irmaos_Conjuges  Pais_Filhos Bilhete     Tarifa   Cabine  \
# ...

# %%
df_titanic.describe()
# Out:
#             Classe   Sobreviveu        Idade  Irmaos_Conjuges  Pais_Filhos  \
# count  1309.000000  1309.000000  1046.000000      1309.000000  1309.000000
# mean      2.294882     0.381971    29.881138         0.498854     0.385027
# std       0.837836     0.486055    14.413493         1.041658     0.865560
# min       1.000000     0.000000     0.170000         0.000000     0.000000
# 25%       2.000000     0.000000    21.000000         0.000000     0.000000
# 50%       3.000000     0.000000    28.000000         0.000000     0.000000
# 75%       3.000000     1.000000    39.000000         1.000000     0.000000
# max       3.000000     1.000000    80.000000         8.000000     9.000000
#
#          ID_Corpo
# count  121.000000
# mean   160.809917
# std     97.696922
# min      1.000000
# 25%     72.000000
# 50%    155.000000
# 75%    256.000000
# max    328.000000

# %%
df_titanic['Sobreviveu'].sum()
# Out:
# np.int64(500)

# %%
df_titanic.nunique()
# Out:
# Classe                3
# Sobreviveu            2
# Nome               1307
# Sexo                  2
# Idade                98
# Irmaos_Conjuges       7
# Pais_Filhos           8
# Bilhete             929
# Tarifa              281
# Cabine              186
# Porto_Embarque        3
# Bote_SalvaVidas      27
# ID_Corpo            121
# Origem_Destino      369
# dtype: int64
